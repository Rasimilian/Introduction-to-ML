# %% [markdown]
# # Construct a decision tree structure of depth 2

# %% [markdown]
# $$ X_{train} = \begin{array}{|c|c|c|}
# \hline
# \text{} & \text{Feature 1} & \text{Feature 2} & \text{Feature 3} & \text{Target variable} \\ \hline
# \hline
# \text{Day} & \text{Outlook} & \text{Humidity } & \text{Wind} & \text{Play} \\ \hline
# 1 & Sunny & High & Weak & No \\
# 2 & Sunny & High & Strong & No \\
# 3 & Overcast & High & Weak & Yes \\
# 4 & Rain & High & Weak & Yes \\
# 5 & Rain & Normal & Weak & Yes \\
# 6 & Rain & Normal & Strong & No \\
# 7 & Overcast & Normal & Strong & Yes \\
# 8 & Sunny & High & Weak & No \\
# 9 & Sunny & Normal & Weak & Yes \\
# 10 & Rain & Normal & Weak & Yes \\ \hline
# \end{array} $$
#
# * ***The tree may not be optimal.***
# * ***Calculate the Gini index and the Entropy at each node.***
