# %% [markdown]
# # Classification: Logistic Regression

# %% [markdown]
# <img src="https://developers.google.com/static/machine-learning/crash-course/logistic-regression/images/sigmoid_function_with_axes.png" width="600">

# %%
import numpy as np
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
# Use 2 types of iris 
iris = load_iris(as_frame=True)
X = ____
y = ____

# %%
____, ____, ____, ____ = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)


model = LogisticRegression()
model.fit(____, ____)

y_pred = model.predict(____)

print(f"Accuracy: {accuracy_score(____, ____):.2f}")

plt.scatter(____, ____, c=____, edgecolors='k', cmap=plt.cm.RdYlBu)
plt.xlabel('sepal length')
plt.ylabel('sepal width')
plt.show()
