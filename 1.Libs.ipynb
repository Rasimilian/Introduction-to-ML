# %% [markdown]
# # Installation

# %%
# Download libraries
! pip install numpy, matplotlib, pandas, scikit-learn, seaborn

# %%
import numpy as np
import pandas as pd
import sklearn as sk
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

# %%
print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)
print("Sklearn version:", sk.__version__)
print("Seaborn version:", sns.__version__)
print("Matplotlib version:", matplotlib.__version__)

# %% [markdown]
# ## Numpy

# %%
# Create two 3D-arrays of shape (x,y,z)
# Calculate product by a scalar
# Calculate sum, dot product, element-wise product, cross product, inverse matrix
# Print the resulting shapes

# %% [markdown]
# ## Pandas

# %%
df = pd.DataFrame({"Name": ["Andrew", "Anton", "Anna"], "Age": [22, 21, 21]})
df.head()

# %%
titanic = sns.load_dataset('titanic')
titanic.head()

# %%
# Calculate max, min, median, mean, std, count for numerical columns
# Group by gender
# Create a pivot table by (survived, sex, class, mean)

# %% [markdown]
# ## Matplotlib

# %%
# Plot Age, Fare histograms
# Plot boxplot for class and age columns
