# %% [markdown]
# # Fill in the gaps

# %%
import numpy as np
import pandas as ____
import matplotlib.pyplot as ____

# %% [markdown]
# ## Task 1

# %%
# Create list and array
data = ____

array_data = ____.____(data)

assert type(data) == list
assert type(array_data) == np.ndarray

# %% [markdown]
# ## Task 2

# %%
# Create two arrays
arr1 = ____.____([1, 2, 3, 4, 5])
arr2 = ____.____([6, 7, 8, 9, 10])

sum_result = ____ + ____
mult_result = ____ * ____  # element-wise multiplication
dot_mult_result = arr1.____(arr2)  # scalar multiplication
mean_value = np.____(arr1)

np.testing.assert_equal(sum_result, np.array([7, 9, 11, 13, 15]))
np.testing.assert_equal(mult_result, np.array([6, 14, 24, 36, 50]))
assert mean_value == 3
assert dot_mult_result == 130

# %% [markdown]
# ## Task 3

# %%
# Create 3х4 matrix
matrix = ____

shape = matrix.____ 
assert shape == (3, 4)

transposed = ____.____(matrix)
transposed_shape = transposed.____


assert transposed_shape == (____, ____)
