# %% [markdown]
# # Build a linear hard-margin SVM model

# %% [markdown]
# Define the hyper-plane equation $\mathbf{w} \cdot \mathbf{x} + b = 0$, the support vectors and the margin width for the data below
# $$ X_{train} = \begin{array}{|c|c|c|}
# \hline
# \text{Feature 1} & \text{Feature 2} & \text{Target variable} \\ \hline
# \hline
# \text{X} & \text{Y} & \text{Class} \\ \hline
# 1 & 1 & +1 \\
# 2 & 2 & +1 \\
# 2 & 0 & +1 \\
# 0 & 1 & -1 \\
# 1 & 0 & -1 \\ \hline
# \end{array} $$
