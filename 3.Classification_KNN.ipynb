# %% [markdown]
# # Classification

# %% [markdown]
# <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSDVU9o9QPlbt7XVpTwAlfzvE5dYHEWeF0dkg&s" width="400">

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
iris = load_iris(as_frame=True)
X = pd.DataFrame(
    data=iris.data,
    columns=iris.feature_names)
y = iris.target
print(f"Flower types: {iris.target_names}")
X

# %%
iris.frame["target"] = iris.target_names[iris.target]
_ = sns.pairplot(iris.frame, hue="target")

# %%
____, ____, ____, ____ = train_test_split(____.to_numpy(), ____, test_size=0.2, random_state=42)

model = KNeighborsClassifier(n_neighbors=____)
model.fit(____, ____)

____ = model.predict(____)
print(f"True values: {____}")
print(f"Prediction: {____}")

# Prediction accuracy
accuracy = accuracy_score(____, ____)
print(f"Accuracy: {accuracy * 100:.2f}%")

print(f"Report:\n {classification_report(____, ____, target_names=iris.target_names)}")

# Fill new flower parameters
new_flower = [[____, ____, ____, ____]]
prediction = model.predict(new_flower)
print(f"New flower is: {iris.target_names[prediction][0]}")

# %%
# Prediction errors
cm = confusion_matrix(____, ____)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=iris.target_names,
            yticklabels=iris.target_names)
plt.title('Confusion matrix')
plt.ylabel('True')
plt.xlabel('Prediction')
plt.show()

# %% [markdown]
# # Personal task

# %% [markdown]
# * Implement accuracy, precision, recall, f1-score metrics.
# * Implement the KNN model.
# * Download the MNIST Dataset and describe it.
# * Split your dataset into 80%/20% train/test sets.
# * Normalize the data with mean and standard deviation if necessary.
# * Based on the analysis, select the appropriate number of neighbors.
# * Implement, train and compare the Weighted KNN model with the KNN model.

# %%
def accuracy():
    pass


def precision():
    pass


def recall():
    pass


def f1_score():
    pass

# %%
class MyKNN:
    def __init__(self, k=3, distance_metric='euclidean'):
        self.k = k
        self.distance_metric = distance_metric
        self.X_train = None
        self.y_train = None
        
    def fit(self, X, y):
        pass
        
    def _euclidean_distance(self, x1, x2):
        pass
    
    def _manhattan_distance(self, x1, x2):
        pass
    
    def _chebyshev_distance(self, x1, x2):
        pass
    
    def _calculate_distance(self, x1, x2):
        if self.distance_metric == 'euclidean':
            return self._euclidean_distance(x1, x2)
        elif self.distance_metric == 'manhattan':
            return self._manhattan_distance(x1, x2)
        elif self.distance_metric == 'chebyshev':
            return self._chebyshev_distance(x1, x2)
        else:
            raise ValueError(f"Error: {self.distance_metric}")
    
    def _predict_one(self, x):
        pass
    
    def predict(self, X):
        pass


class MyWeightedKNN(KNN):
    def __init__(self, k=3, distance_metric='euclidean', weight_power=2):
        super().__init__(k, distance_metric)
        self.weight_power = weight_power
        
    def _predict_one(self, x):
        pass
