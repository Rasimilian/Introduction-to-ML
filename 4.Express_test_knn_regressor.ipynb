# %% [markdown]
# # Make estimations on the target value using KNN-Regressor

# %% [markdown]
# $$ X_{train} = \begin{array}{|c|c|c|}
# \hline
# \text{Feature 1} & \text{Feature 2} & \text{Target variable} \\ \hline
# \hline
# \text{Height} & \text{Age} & \text{Weight} \\ \hline
# 150 & 15 & 50 \\
# 180 & 30 & 82 \\
# 165 & 25 & 68 \\
# 160 & 12 & 45 \\
# 185 & 40 & 90 \\
# 170 & 28 & 72 \\ \hline
# \end{array} $$
#
# $$ X_{test} = \begin{array}{|c|c|c|}
# \hline
# \text{Feature 1} & \text{Feature 2} & \text{Target variable} \\ \hline
# \hline
# \text{Height} & \text{Age} & \text{Weight} \\ \hline
# 172 & 26 & ? \\ \hline
# \end{array} $$
#
# * ***Select any number of neighbors.***
# * ***Use Euclidean Distance.***
# * ***No need for normalization.***
