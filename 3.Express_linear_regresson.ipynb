# %% [markdown]
# # Make estimations on Linear Regression coefficients

# %% [markdown]
# $$ x \sim U(0, 1)$$
# $$ y = 10 \cdot x + 1$$
# $$ z = 2 \cdot x^{2026} + 8$$

# %% [markdown]
# ## Task 1

# %% [markdown]
# Estimate A and B of:
# $$ y = A \cdot x + B$$

# %% [markdown]
# ## Task 2

# %% [markdown]
# Estimate A and B of:
# $$ z = A \cdot x + B$$

# %% [markdown]
# ## Task 3

# %% [markdown]
# Estimate A and B of:
# $$ z = A \cdot y + B$$
